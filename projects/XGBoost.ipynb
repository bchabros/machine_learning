# %%
# import bibliotek
import pandas as pd
import numpy as np 
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import  balanced_accuracy_score, roc_auc_score, make_scorer
from sklearn.model_selection import GridSearchCV # walidacja krzyzowa 
from sklearn.metrics import confusion_matrix
from sklearn.metrics import  plot_confusion_matrix

# %%
# import danych 
df = pd.read_csv('telco_customer_churn.csv')
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customerID</th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>...</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
# ...

# %%
df.drop(['customerID'], axis=1, inplace=True)

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.columns = df.columns.str.replace(' ', '_')
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df['MultipleLines'].replace(' ', '_', regex=True, inplace=True)
df['PaymentMethod'].replace(' ', '_', regex=True, inplace=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df['MultipleLines'].unique()

# %%
df['PaymentMethod'].unique()

# %%
df.dtypes

# %%
df['PhoneService'].unique()

# %%
df['TotalCharges'].unique()

# %%
# proba zmiany na numeryczna niestety sie nie udala
# df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])

# %%
# drugie podejscie
len(df.loc[df['TotalCharges'] == ' '])
# Out:
# 11

# %%
df.loc[df['TotalCharges'] == ' ']
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.loc[(df['TotalCharges'] == ' '), 'TotalCharges'] = 0

# %%
df.loc[df['tenure'] == 0]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'])
df.dtypes

# %%
df.replace(' ', '_', regex=True, inplace=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>Churn</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
X = df.drop('Churn', axis=1).copy()
y = df['Churn'].copy()

# %%
X.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>DeviceProtection</th>
#       <th>TechSupport</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>PaymentMethod</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
y.head()

# %%
X.dtypes

# %%
# rozbicie jednej zmiennej na kilka zero-jedynkowych
pd.get_dummies(X, columns=['PaymentMethod']).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>gender</th>
#       <th>SeniorCitizen</th>
#       <th>Partner</th>
#       <th>Dependents</th>
#       <th>tenure</th>
#       <th>PhoneService</th>
#       <th>MultipleLines</th>
#       <th>InternetService</th>
#       <th>OnlineSecurity</th>
#       <th>OnlineBackup</th>
#       <th>...</th>
#       <th>StreamingTV</th>
#       <th>StreamingMovies</th>
#       <th>Contract</th>
#       <th>PaperlessBilling</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>PaymentMethod_Bank_transfer_(automatic)</th>
#       <th>PaymentMethod_Credit_card_(automatic)</th>
# ...

# %%
X_encoded = pd.get_dummies(X, columns=['gender',
                                       'SeniorCitizen',
                                       'Partner',
                                       'Dependents',
                                       'PhoneService',
                                       'MultipleLines',
                                       'InternetService',
                                       'OnlineSecurity',
                                       'OnlineBackup',
                                       'DeviceProtection',
                                       'TechSupport',
                                       'StreamingTV',
                                       'StreamingMovies',
                                       'Contract',
                                       'PaperlessBilling',
                                       'PaymentMethod'])
X_encoded.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tenure</th>
#       <th>MonthlyCharges</th>
#       <th>TotalCharges</th>
#       <th>gender_Female</th>
#       <th>gender_Male</th>
#       <th>SeniorCitizen_0</th>
#       <th>SeniorCitizen_1</th>
#       <th>Partner_No</th>
#       <th>Partner_Yes</th>
#       <th>Dependents_No</th>
#       <th>...</th>
#       <th>StreamingMovies_Yes</th>
#       <th>Contract_Month-to-month</th>
#       <th>Contract_One_year</th>
#       <th>Contract_Two_year</th>
#       <th>PaperlessBilling_No</th>
#       <th>PaperlessBilling_Yes</th>
#       <th>PaymentMethod_Bank_transfer_(automatic)</th>
# ...

# %%
y.replace('No', 0, inplace=True)
y.replace('Yes', 1, inplace=True)
y = pd.to_numeric(y)
sum(y)/len(y)
# Out:
# 0.2653698707936959

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, random_state=42, stratify=y)

# %%
print(sum(y_train)/len(y_train))
print(sum(y_test)/len(y_test))
# Out:
# 0.2654297614539947
# 0.26519023282226006

# %%
clf_xgb = xgb.XGBClassifier(objective='binary:logistic', missing=1, seed=42, use_label_encoder=False)
clf_xgb.fit(X_train, 
            y_train,
            verbose=True,
            early_stopping_rounds=10,
            eval_metric='aucpr',
            eval_set=[(X_test, y_test)])
# Out:
# [0]	validation_0-aucpr:0.63160
# [1]	validation_0-aucpr:0.64538
# [2]	validation_0-aucpr:0.64402
# [3]	validation_0-aucpr:0.64461
# [4]	validation_0-aucpr:0.64114
# [5]	validation_0-aucpr:0.64016
# [6]	validation_0-aucpr:0.64620
# [7]	validation_0-aucpr:0.64003
# [8]	validation_0-aucpr:0.63913
# [9]	validation_0-aucpr:0.64153
# [10]	validation_0-aucpr:0.64172
# [11]	validation_0-aucpr:0.63950
# [12]	validation_0-aucpr:0.63687
# [13]	validation_0-aucpr:0.63473
# [14]	validation_0-aucpr:0.63442
# [15]	validation_0-aucpr:0.63634
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=1,
#               monotone_constraints='()', n_estimators=100, n_jobs=2,
# ...

# %%
y_pred = clf_xgb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[1166  128]
#  [ 225  242]]

# %%
# budowa najlepszego modelu optymalizacja walidacji krzyzowej
clf_xgb = xgb.XGBClassifier(seed=42,
                            objective='binary:logistic',
                            gamma=0.25,
                            learn_rate=0.1,
                            max_depth=4,
                            reg_lambda=10,
                            scale_pos_weight=3,
                            subsample=0.9,
                            colsample_bytree=0.5,
                            missing=1,
                            use_label_encoder=False)
clf_xgb.fit(X_train,
            y_train,
            verbose=True,
            early_stopping_rounds=10,
            eval_metric='aucpr',
            eval_set=[(X_test, y_test)])
# Out:
# [20:20:28] WARNING: ../src/learner.cc:576:
# Parameters: { "learn_rate" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	validation_0-aucpr:0.58915
# [1]	validation_0-aucpr:0.59954
# [2]	validation_0-aucpr:0.63385
# [3]	validation_0-aucpr:0.63774
# [4]	validation_0-aucpr:0.64064
# [5]	validation_0-aucpr:0.62895
# [6]	validation_0-aucpr:0.63460
# [7]	validation_0-aucpr:0.63610
# [8]	validation_0-aucpr:0.63589
# [9]	validation_0-aucpr:0.64528
# [10]	validation_0-aucpr:0.65139
# [11]	validation_0-aucpr:0.65298
# [12]	validation_0-aucpr:0.65317
# [13]	validation_0-aucpr:0.65199
# [14]	validation_0-aucpr:0.65126
# [15]	validation_0-aucpr:0.65135
# [16]	validation_0-aucpr:0.65207
# [17]	validation_0-aucpr:0.65465
# ...

# %%
y_pred = clf_xgb.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[934 360]
#  [ 90 377]]

# %%
clf_xgb = xgb.XGBClassifier(seed=42,
                            objective='binary:logistic',
                            gamma=0.25,
                            learn_rate=0.1,
                            max_depth=4,
                            reg_lambda=10,
                            scale_pos_weight=3,
                            subsample=0.9,
                            colsample_bytree=0.5,
                            missing=1,
                            use_label_encoder=False,
                            n_estimator=1)
clf_xgb.fit(X_train, y_train)
# Out:
# [20:20:29] WARNING: ../src/learner.cc:576:
# Parameters: { "learn_rate", "n_estimator" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [20:20:29] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.5,
#               enable_categorical=False, gamma=0.25, gpu_id=-1,
#               importance_type=None, interaction_constraints='', learn_rate=0.1,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=4,
# ...

# %%
bst = clf_xgb.get_booster()
for importance_type in ('weight', 'gain', 'cover', 'total_gain', 'total_cover'):
    print('%s: ' % importance_type, bst.get_score(importance_type=importance_type))

node_params = {'shape': 'box',
               'style': 'filled, rounded',
               'fil;color': '#78cbe'}
leaf_params = {'shape': 'box',
               'style': 'filled',
               'fillcolor': '#e48038'}

xgb.to_graphviz(clf_xgb, num_trees=0, size='10,10',
                condition_node_params=node_params,
                leaf_node_params=leaf_params)
# Out:
# weight:  {'tenure': 165.0, 'MonthlyCharges': 278.0, 'TotalCharges': 288.0, 'gender_Female': 17.0, 'gender_Male': 15.0, 'SeniorCitizen_0': 24.0, 'SeniorCitizen_1': 10.0, 'Partner_No': 17.0, 'Partner_Yes': 7.0, 'Dependents_No': 26.0, 'Dependents_Yes': 7.0, 'PhoneService_No': 7.0, 'PhoneService_Yes': 9.0, 'MultipleLines_No': 21.0, 'MultipleLines_Yes': 19.0, 'InternetService_DSL': 12.0, 'InternetService_Fiber_optic': 18.0, 'InternetService_No': 6.0, 'OnlineSecurity_No': 20.0, 'OnlineSecurity_Yes': 11.0, 'OnlineBackup_No': 16.0, 'OnlineBackup_Yes': 20.0, 'DeviceProtection_No': 10.0, 'DeviceProtection_Yes': 17.0, 'TechSupport_No': 19.0, 'TechSupport_Yes': 23.0, 'StreamingTV_No': 10.0, 'StreamingTV_Yes': 9.0, 'StreamingMovies_No': 8.0, 'StreamingMovies_Yes': 19.0, 'Contract_Month-to-month': 25.0, 'Contract_One_year': 17.0, 'Contract_Two_year': 15.0, 'PaperlessBilling_No': 26.0, 'PaperlessBilling_Yes': 11.0, 'PaymentMethod_Bank_transfer_(automatic)': 15.0, 'PaymentMethod_Credit_card_(automat
# ...
